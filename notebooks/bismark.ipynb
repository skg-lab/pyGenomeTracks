# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(100)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib as mpl
mpl.rcParams.update(_VSCode_defaultMatplotlib_Params)
sns.set_style(rc = {'figure.facecolor':'white'})
# Out:
# /Users/yasumizuyoshiaki/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /Users/yasumizuyoshiaki/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %%
df = pd.read_csv('skggenometracks/tests/test_data/mini.Foxp3.bismark.cov.gz', sep='\t', header=None)
df.columns = ['chr', 'start', 'end', 'rate', 'met', 'demet']
df.head()
# Out:
#     chr    start      end        rate  met  demet
# 0  chrX  7558951  7558951  100.000000   14      0
# 1  chrX  7558952  7558952  100.000000    9      0
# 2  chrX  7558984  7558984  100.000000   13      0
# 3  chrX  7558985  7558985   88.888889    8      1
# 4  chrX  7559101  7559101   88.888889    8      1

# %%
chrom_region, start_region, end_region = 'X', 7558768, 7616151
df_q = df[df['chr'] == 'chr'+str(chrom_region)]
df_q = df_q.query('start <= @end_region & end >= @start_region')
df_q.head()
# Out:
#     chr    start      end        rate  met  demet
# 0  chrX  7558951  7558951  100.000000   14      0
# 1  chrX  7558952  7558952  100.000000    9      0
# 2  chrX  7558984  7558984  100.000000   13      0
# 3  chrX  7558985  7558985   88.888889    8      1
# 4  chrX  7559101  7559101   88.888889    8      1

# %%
fig = plt.figure()

ax = fig.add_subplot(1,1,1)

ax.scatter(df_q['start'], df_q['rate'])
ax.set_ylim(-5,105)
# Out:
# (-5, 105)
